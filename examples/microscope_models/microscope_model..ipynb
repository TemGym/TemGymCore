# %%
from temgym_core import MicroscopeModel, LensConfig

# %%
voltage = 200e3  # [V]

condenser_lens_one = LensConfig(
    name="Condenser Lens 1",
    z_position=1,
    turns=2000,

microscope_model = MicroscopeModel(
